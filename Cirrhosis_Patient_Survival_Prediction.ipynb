# %% [markdown]
# <a href="https://colab.research.google.com/github/Ykomash/ML_Projects/blob/main/Cirrhosis_Patient_Survival_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Raw_df = pd.read_csv("/content/cirrhosis.csv")
Raw_df
# Out:
#       ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly  \
# 0      1     400      D  D-penicillamine  21464   F       Y            Y
# 1      2    4500      C  D-penicillamine  20617   F       N            Y
# 2      3    1012      D  D-penicillamine  25594   M       N            N
# 3      4    1925      D  D-penicillamine  19994   F       N            Y
# 4      5    1504     CL          Placebo  13918   F       N            Y
# ..   ...     ...    ...              ...    ...  ..     ...          ...
# 413  414     681      D              NaN  24472   F     NaN          NaN
# 414  415    1103      C              NaN  14245   F     NaN          NaN
# 415  416    1055      C              NaN  20819   F     NaN          NaN
# 416  417     691      C              NaN  21185   F     NaN          NaN
# 417  418     976      C              NaN  19358   F     NaN          NaN
#
#     Spiders Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
Raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             418 non-null    int64
#  1   N_Days         418 non-null    int64
#  2   Status         418 non-null    object
#  3   Drug           312 non-null    object
#  4   Age            418 non-null    int64
#  5   Sex            418 non-null    object
#  6   Ascites        312 non-null    object
#  7   Hepatomegaly   312 non-null    object
#  8   Spiders        312 non-null    object
#  9   Edema          418 non-null    object
#  10  Bilirubin      418 non-null    float64
#  11  Cholesterol    284 non-null    float64
#  12  Albumin        418 non-null    float64
#  13  Copper         310 non-null    float64
#  14  Alk_Phos       312 non-null    float64
#  15  SGOT           312 non-null    float64
#  16  Tryglicerides  282 non-null    float64
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming Raw_df is your DataFrame

for column in Raw_df.select_dtypes(include=["object"]).columns:
    plt.figure(figsize=(5, 3))
    sns.histplot(data=Raw_df[column].dropna(), bins=20)  # Drop null values before plotting
    plt.title(f"Histogram of {column}")
    plt.show()

# %%
# prompt: show corr matrix for all the numericals

corr_matrix = Raw_df.select_dtypes(include=["int64", "float64"]).corr()

# Display the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Matrix of Numerical Features")
plt.show()

# %%
# prompt: show hist for all colmos

for column in Raw_df.columns:
    plt.figure(figsize=(5, 3))
    sns.histplot(data=Raw_df[column].dropna(), bins=20)  # Drop null values before plotting
    plt.title(f"Histogram of {column}")
    plt.show()

# %%
Raw_df["Status"].value_counts()
# Out:
# C     232
# D     161
# CL     25
# Name: Status, dtype: int64

# %%
drop_df = Raw_df.dropna(subset=["Drug"])
drop_df
# Out:
#       ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly  \
# 0      1     400      D  D-penicillamine  21464   F       Y            Y
# 1      2    4500      C  D-penicillamine  20617   F       N            Y
# 2      3    1012      D  D-penicillamine  25594   M       N            N
# 3      4    1925      D  D-penicillamine  19994   F       N            Y
# 4      5    1504     CL          Placebo  13918   F       N            Y
# ..   ...     ...    ...              ...    ...  ..     ...          ...
# 307  308    1153      C  D-penicillamine  22347   F       N            Y
# 308  309     994      C          Placebo  21294   F       N            N
# 309  310     939      C  D-penicillamine  22767   F       N            N
# 310  311     839      C  D-penicillamine  13879   F       N            N
# 311  312     788      C          Placebo  12109   F       N            N
#
#     Spiders Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# ...

# %%
drop_df.describe().style.format("{:.2f}")
drop_df.describe()
# Out:
#                ID       N_Days           Age   Bilirubin  Cholesterol  \
# count  312.000000   312.000000    312.000000  312.000000   284.000000
# mean   156.500000  2006.362179  18269.442308    3.256090   369.510563
# std     90.210864  1123.280843   3864.805407    4.530315   231.944545
# min      1.000000    41.000000   9598.000000    0.300000   120.000000
# 25%     78.750000  1191.000000  15427.750000    0.800000   249.500000
# 50%    156.500000  1839.500000  18187.500000    1.350000   309.500000
# 75%    234.250000  2697.250000  20715.000000    3.425000   400.000000
# max    312.000000  4556.000000  28650.000000   28.000000  1775.000000
#
#           Albumin      Copper      Alk_Phos        SGOT  Tryglicerides  \
# count  312.000000  310.000000    312.000000  312.000000     282.000000
# mean     3.520000   97.648387   1982.655769  122.556346     124.702128
# std      0.419892   85.613920   2140.388824   56.699525      65.148639
# ...

# %%
drop_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 312 entries, 0 to 311
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             312 non-null    int64
#  1   N_Days         312 non-null    int64
#  2   Status         312 non-null    object
#  3   Drug           312 non-null    object
#  4   Age            312 non-null    int64
#  5   Sex            312 non-null    object
#  6   Ascites        312 non-null    object
#  7   Hepatomegaly   312 non-null    object
#  8   Spiders        312 non-null    object
#  9   Edema          312 non-null    object
#  10  Bilirubin      312 non-null    float64
#  11  Cholesterol    284 non-null    float64
#  12  Albumin        312 non-null    float64
#  13  Copper         310 non-null    float64
#  14  Alk_Phos       312 non-null    float64
#  15  SGOT           312 non-null    float64
#  16  Tryglicerides  282 non-null    float64
# ...

# %%
drop_df[drop_df["Cholesterol"].isna()]
# Out:
#       ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly  \
# 13    14    1217      D          Placebo  20535   M       Y            Y
# 39    40    4467      C  D-penicillamine  17046   F       N            N
# 40    41    1350      D  D-penicillamine  12285   F       N            Y
# 41    42    4453      C          Placebo  12307   F       N            Y
# 44    45    4025      C          Placebo  15265   F       N            N
# 48    49     708      D          Placebo  22336   F       N            Y
# 52    53    1000      D  D-penicillamine  24621   F       N            Y
# 69    70    3458      C  D-penicillamine  20600   F       N            N
# 94    95     130      D          Placebo  16944   F       Y            Y
# 95    96    3850      C  D-penicillamine  17841   F       N            N
# 105  106    3222      D  D-penicillamine  25023   F       Y            Y
# 122  123     971      D  D-penicillamine  16736   F       N            Y
# ...

# %%
# prompt: scater plot of Cholesterol with SGOT and Bilirubin

plt.figure(figsize=(6, 3))
sns.scatterplot(data=drop_df, x="Cholesterol", y="SGOT")
plt.title("Scatter Plot of Cholesterol with SGOT and Bilirubin")
plt.show()

# %%
plt.figure(figsize=(6, 3))
sns.scatterplot(data=drop_df, x="Cholesterol", y="Bilirubin")
plt.title("Scatter Plot of Cholesterol with SGOT and Bilirubin")
plt.show()
